# %% [markdown]
# # Try preprocessing data

# %%
import dataloader
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import models
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision
import os
import time
from torch_geometric.nn import GATv2Conv, global_mean_pool
# reload library
import importlib
import cv2
import utils as ut
import pandas as pd
import DataDLC

# %%
importlib.reload(dataloader)
importlib.reload(DataDLC)
# Out:
# <module 'DataDLC' from 'c:\\Users\\jalvarez\\Documents\\Code\\GitHubCOde\\Behavioral_Tagging_of_Mice_in_multiple_Mice_dataset_using_Deep_Learning\\src\\DataDLC.py'>

# %% [markdown]
# **Load Data**

# %%
data_path = r'c:\Users\jalvarez\Documents\Data\DataLoader_Baseline_models\MDXCV_mal_Test_20DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5'

data_dlc = DataDLC.DataDLC(data_path)

# %%
#data_dlc.preprocess()

# %%
data_dlc.coords.isna().sum().sum()
# Out:
# 5319

# %%
prev = data_dlc.coords['individual1']['Nose']['x']

# %%
diff = data_dlc.get_statistics_on_jumps(plot = True)
print('min', diff.min())
print('max', diff.max())
print('mode', diff.mode())
print('median', diff.median())
print('95 upper percentile', diff.quantile(0.95))
# Out:
# Mean of the jumps for individual1 and Center: 4.701168458466205
# Standard deviation of the jumps for individual1 and Center: 5.730266463228811
# min 0.0
# max 70.2941844109454
# mode 0    0.0
# dtype: float64
# median 2.6608908282753867
# 95 upper percentile 16.241156227449167

# %%
# Deactivate all warnings
import warnings

warnings.filterwarnings('ignore')

data_dlc.iterative_jump_detection(threshold_hard=[10000,10000], threshold_soft_min=30, threshold_soft_max=8,  verbose=True, tol=1e-9)
#data_dlc.iterative_jump_detection(verbose=True, tol=1e-9)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 16

# %%
data_dlc.detect_isolated_jumps(threshold_soft_min=30, threshold_soft_max=8)

# %%
print('Number of jumps detected:', data_dlc.mask_jumps.sum().sum())
# Out:
# Number of jumps detected: 16

# %%
# Count trues in mask_jumps
print(data_dlc.mask_jumps.sum().sum())
# Out:
# 16

# %%
for ind in data_dlc.individuals:
    for part in data_dlc.body_parts:
        if data_dlc.mask_jumps[ind][part].sum() > 0:
            print('Thers a jump in individual', ind, 'part', part, 'at frames', np.where(data_dlc.mask_jumps[ind][part])[0])
# Out:
# Thers a jump in individual individual2 part Center at frames [2464 2465]
# Thers a jump in individual individual2 part Center_head at frames [2408 2409]
# Thers a jump in individual individual2 part Left_bhip at frames [1456 1457]
# Thers a jump in individual individual2 part Left_fhip at frames [2463]
# Thers a jump in individual individual2 part Nose at frames [1414]
# Thers a jump in individual individual2 part Spine_1 at frames [2463]
# Thers a jump in individual individual2 part Spine_1-center at frames [2464]
# Thers a jump in individual individual2 part Spine_2 at frames [2464]
# Thers a jump in individual individual2 part Spine_center-2 at frames [1255 2464]
# Thers a jump in individual individual2 part Tail_1 at frames [886]
# Thers a jump in individual individual2 part Tail_2 at frames [2304]
# Thers a jump in individual individual2 part Tail_tip at frames [610]

# %%
prev = data_dlc.old_coords
coords = data_dlc.coords

# print differences 
for ind in data_dlc.individuals:
    for part in data_dlc.body_parts:
       
        print('Individual', ind, 'part', part, ' there are differences in the following frames ', np.where(coords[ind][part]!=prev[ind][part])[0])
# Out:
# Individual individual1 part Center  there are differences in the following frames  []
# Individual individual1 part Center_head  there are differences in the following frames  [2053 2054 2055 2055 2056 2056 2057 2057 2058 2058]
# Individual individual1 part Left_bhip  there are differences in the following frames  []
# Individual individual1 part Left_ear  there are differences in the following frames  []
# Individual individual1 part Left_fhip  there are differences in the following frames  []
# Individual individual1 part Left_mid  there are differences in the following frames  [545 545 546 546 547 547 548 548 549 549 550 550]
# Individual individual1 part Nose  there are differences in the following frames  [  70   70   71   71   72   72   73   73   74   74   75   75   76   76
#    77   77   78   78   79   79   80   80   81   81   82   82   83   83
#    84   84   85   85   86   86   87   87   88   88   89   89   90   90
#    91   91   92   92   93   93  279  279  280  280  281  281  282  282
#   283  283  284  284  285  285 1705 1706 1707 1707 1708 1708 1709 1709
#  1710 1710 1775 1776 1776 1777 1777 1778 1778 1779 1779 1890 1891 1891
#  1892 1892 1893 1893 1894 1894 1895 1895 1896 1896 1897 1897 1898 1898
#  1899 1899 1900 1900 1901 1901 1902 1902 1903 1903 1904 1904 1905 1905
#  1906 1906 1907 1907 1908 1908 1983 1984 1985 1985 1986 1986 1987 1987
#  1988 1988 1989 1989 1990 1990]
# Individual individual1 part Right_bhip  there are differences in the following frames  [185 186 187 187 188 188 189 189 190 190 191 191 192 192 193 193 194 194
#  639 639 640 641]
# Individual individual1 part Right_ear  there are differences in the following frames  [2482 2482 2483 2483 2484 2484 2485 2485 2486 2486 2487 2487 2488 2488
#  2489 2489 2490 2490]
# Individual individual1 part Right_fhip  there are differences in the following frames  [1065 1065 1066 1066 1067 1067 1068 1068 1069 1069 2482 2482 2483 2483
#  2484 2484 2485 2485 2486 2486 2487 2487 2488 2488 2489 2489 2490 2490]
# Individual individual1 part Right_mid  there are differences in the following frames  [2482 2483 2484 2484 2485 2485 2486 2486 2487 2487 2488 2488 2489 2489
#  2490 2490]
# Individual individual1 part Spine_1  there are differences in the following frames  []
# Individual individual1 part Spine_1-center  there are differences in the following frames  []
# Individual individual1 part Spine_2  there are differences in the following frames  [639 639 640 641]
# Individual individual1 part Spine_2-base  there are differences in the following frames  [639 639 640 641]
# Individual individual1 part Spine_center-2  there are differences in the following frames  [639 640 641]
# Individual individual1 part Tail_1  there are differences in the following frames  [639 640 641]
# Individual individual1 part Tail_2  there are differences in the following frames  []
# Individual individual1 part Tail_3  there are differences in the following frames  [ 502  502  503  503  504  504  505  505 2565 2566 2567 2567 2568 2568
#  2569 2569 2570 2570 2602 2603 2603 2604 2604 2605 2605 2606 2606 2607
#  2607]
# Individual individual1 part Tail_4  there are differences in the following frames  [ 500  502  502  503  503  504  504  505  505 1206 1208 1208 1209 1209
#  1210 1210 1211 1211 1212 1212 2566 2567 2568 2568 2569 2569 2570 2570
#  2571 2571]
# Individual individual1 part Tail_base  there are differences in the following frames  [639 640 641]
# Individual individual1 part Tail_tip  there are differences in the following frames  [ 502  502  503  503  504  504  505  505  506  506 1206 1208 1208 1209
#  1209 1210 1210 1211 1211 1212 1212 2565 2566 2567 2567 2568 2568 2569
#  2569 2570 2570 2571 2571]
# Individual individual1 part Center of mass  there are differences in the following frames  []

# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.99it/s]

# %%
if True:
    data_dlc.remove_outlier_bouts(threshold_split_tracklets=40, threshold_jump=100, percentage_gap_neigh=0.2, verbose=True)
# Out:
# Outlier bout detected between 334 and 347  of individual individual1 and body part Nose
# 	 Jump between tracklet is 108.67528891150923
# Outlier bout detected between 343 and 347  of individual individual1 and body part Right_ear
# 	 Jump between tracklet is 121.56883285612315
# Outlier bout detected between 893 and 893  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 153.662876121723
# Outlier bout detected between 1208 and 1210  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 101.32405165606043
# Outlier bout detected between 219 and 225  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 178.5889775574069
# Outlier bout detected between 1365 and 1367  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 116.5297242809748
# Outlier bout detected between 1501 and 1503  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 116.60871790736745
# Outlier bout detected between 893 and 893  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 207.81582311508424
# Outlier bout detected between 1356 and 1358  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 146.0615770488598
# Outlier bout detected between 2129 and 2129  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 141.9681111411996
# Outlier bout detected between 2132 and 2133  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 149.88732955123328
# Outlier bout detected between 1332 and 1333  of individual individual2 and body part Nose
# 	 Jump between tracklet is 135.96439646098534
# Outlier bout detected between 1334 and 1400  of individual individual2 and body part Nose
# 	 Jump between tracklet is 127.84273076323113
# Outlier bout detected between 977 and 978  of individual individual2 and body part Right_bhip
# 	 Jump between tracklet is 103.50882527108496
# Outlier bout detected between 883 and 1219  of individual individual2 and body part Spine_2
# 	 Jump between tracklet is 125.03253452601842
# Outlier bout detected between 893 and 893  of individual individual2 and body part Tail_1
# 	 Jump between tracklet is 157.12831103591742
# Outlier bout detected between 894 and 1145  of individual individual2 and body part Tail_1
# 	 Jump between tracklet is 157.57911298455775
# Outlier bout detected between 2279 and 2281  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 115.70274407931664
# Outlier bout detected between 303 and 304  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 113.05080344694592
# Outlier bout detected between 534 and 536  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 122.26292369169923
# Outlier bout detected between 1320 and 1322  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 126.36751715531962
# Outlier bout detected between 1501 and 1503  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 124.15441007068578
# Outlier bout detected between 2127 and 2133  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 134.02181879920886
# Outlier bout detected between 893 and 893  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 203.93214502868352
# Outlier bout detected between 1501 and 1503  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 123.36546606729131
# Outlier bout detected between 2127 and 2132  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 169.2820904569901
# Outlier bout detected between 2179 and 2183  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 103.49700000000001
# Outlier bout detected between 2184 and 2186  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 117.2199190240294
# Outlier bout detected between 2283 and 2289  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 125.53752833779559
# Outlier bout detected between 2305 and 2307  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 113.69280110895326
# Outlier bout detected between 2548 and 2550  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 100.39146708694797
# Outlier bout detected between 663 and 663  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 117.70380354399254
# Outlier bout detected between 1666 and 1680  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 148.66392282906565
# Outlier bout detected between 2127 and 2132  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 209.59462418594129
# Outlier bout detected between 2314 and 2317  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 125.13297436727058

# %%
print(data_dlc.mask_jumps.sum().sum())
# Out:
# 798

# %%
# Create video with jumps
video_path = r'c:\Users\jalvarez\Documents\Data\DLC_analyzedvid\MDX5CV_wo_tail\MDX5CV male\MDXCV_mal_Test_20.mp4'

data_dlc.create_video(video_path, output_path = r'c:\Users\jalvarez\Documents\presentation\jumps.mp4', plot_prev_coords=True)
# Out:
# 100%|██████████| 2632/2632 [09:52<00:00,  4.44it/s]

# %% [markdown]
# **Check out the mask_jump output**

# %%
import matplotlib.pyplot as plt
# Import Arima model
from statsmodels.tsa.arima.model import ARIMA

# MINIC method to detect p and q for ARIMA

# %%
coords = data_dlc.coords
mask_jumps = data_dlc.mask_jumps
# Mask_jumps has true where jumps were detected
mask_no_jumps = ~mask_jumps

# Try with 'Nose' x coordinate of 'individual2'
x_time_serie_nose_no_jumps = coords['individual2']['Nose']['x'][mask_no_jumps['individual2']['Nose']]
x_time_serie_nose_imputed = coords['individual2']['Nose']['x'][mask_jumps['individual2']['Nose']]
y_time_serie_nose_no_jumps = coords['individual2']['Nose']['y'][mask_no_jumps['individual2']['Nose']]
x_time_serie_nose_jumps = prev[mask_jumps['individual2']['Nose']]
y_time_serie_nose_jumps = prev[mask_jumps['individual2']['Nose']]

# %%
# plot the time series
plt.figure(figsize=(10, 7))
plt.plot(x_time_serie_nose_no_jumps, color='blue', marker='x', linestyle='', label='Original Time Serie')
plt.plot(x_time_serie_nose_jumps, color='red', linestyle='', marker='o', alpha=0.5, label='Detected Jumps')
plt.plot(x_time_serie_nose_imputed, color='green', linestyle='', marker='o', alpha=0.5, label='Imputed Jumps')
# plot lines at each frame
for i in range(len(x_time_serie_nose_no_jumps)):
    plt.axvline(x=i, color='black', alpha=0.1)
#plt.xlim(2197, 2205)
plt.xlim(1410, 1420)
plt.legend()
plt.title('Nose x coordinate of individual2')
plt.show()

# %%
x_time_serie_nose_jumps
# Out:
# 2201    376.833
# Name: x, dtype: float64

# %%
# Fit an ARIMA model
ARIMA_model = ARIMA(x_time_serie_nose_no_jumps, order=(1,1,1))
ARIMA_model_fit = ARIMA_model.fit()
ARIMA_model_fit.summary()
# Out:
# c:\Users\Usuario\anaconda3\envs\deepof\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Usuario\anaconda3\envs\deepof\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Usuario\anaconda3\envs\deepof\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      x   No. Observations:                 2623
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -8950.961
# Date:                Thu, 22 Aug 2024   AIC                          17907.922
# Time:                        10:01:38   BIC                          17925.537
# Sample:                             0   HQIC                         17914.301
#                                - 2623
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8102      0.013     62.488      0.000       0.785       0.836
# ma.L1         -0.2368      0.016    -14.851      0.000      -0.268      -0.206
# sigma2        64.1427      0.544    117.928      0.000      63.077      65.209
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):             53873.55
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.37   Skew:                            -1.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                        25.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # Let's check the bouts jumps

# %%
# Try with 'Right_bhip' x coordinate of 'individual2'
print(mask_jumps['individual2']['Right_bhip'].sum())
x_time_serie_Tail_3_no_jumps = coords['individual2']['Right_bhip']['x'][mask_no_jumps['individual2']['Right_bhip']]
x_time_serie_Tail_3_imputed = coords['individual2']['Right_bhip']['x'][mask_jumps['individual2']['Right_bhip']]
y_time_serie_Tail_3_no_jumps = coords['individual2']['Right_bhip']['y'][mask_no_jumps['individual2']['Right_bhip']]
x_time_serie_Tail_3_jumps = prev[mask_jumps['individual2']['Right_bhip']]
y_time_serie_Tail_3_jumps = prev[mask_jumps['individual2']['Right_bhip']]
# Out:
# 3

# %%
x_time_serie_Tail_3_jumps
# Out:
# 519    143.609
# 520    143.609
# 521    135.593
# Name: x, dtype: float64

# %%
# Plot fitted values603 and 606
plt.plot(x_time_serie_Tail_3_no_jumps[515:530], color='blue', label='Original', marker = 'o', linestyle='None', alpha=0.5)
plt.plot(x_time_serie_Tail_3_jumps, color='red', label='Jumps', marker = 'o', linestyle='None', alpha=0.5)
#plt.plot(ARIMA_model_fit.fittedvalues[700:720], color='red', linestyle='--', label='Fitted')
plt.title('Right_bhip x coordinate of individual2')
plt.xlabel('Frame')
plt.ylabel('X coordinate')
plt.legend()
plt.show()

# %%
ARIMA_model_fit.fittedvalues
# Out:
# 0         0.000000
# 1       511.078211
# 2       515.223555
# 3       514.168022
# 4       513.793124
#            ...
# 2619    507.598824
# 2620    508.188362
# 2621    507.378567
# 2622    516.885784
# 2623    513.972241
# Length: 2623, dtype: float64

# %%
data_dlc.coords['individual2']['Left_ear']['x'].iloc[10:30]
# Out:
# 10    420.038
# 11    392.055
# 12    353.992
# 13    330.081
# 14    312.031
# 15    305.814
# 16    300.652
# 17    300.646
# 18    300.443
# 19    300.438
# 20    300.438
# 21    300.438
# 22    300.438
# 23    300.438
# 24    200.973
# 25    175.392
# 26    160.942
# 27    155.303
# 28    154.776
# 29    154.776
# Name: x, dtype: float64

# %%
data_dlc.coords.isna().sum().sum()
# Out:
# 5641

# %%
data_dlc.coords.head(300)
# Out:
# individuals individual1                                                   \
# bodyparts          Nose                     Left_ear
# coords                x        y likelihood        x        y likelihood
# 0               217.172  182.327        1.0  248.558  198.764        1.0
# 1               217.172  183.464        1.0  248.558  200.210        1.0
# 2               217.172  183.911        1.0  248.558  200.210        1.0
# 3               210.524  183.911        1.0  238.978  199.890        1.0
# 4               197.443  183.464        1.0  222.392  199.890        1.0
# ..                  ...      ...        ...      ...      ...        ...
# 295             221.413  105.932        1.0  205.549  142.719        1.0
# 296             190.808  104.298        1.0  190.919  144.151        1.0
# 297             176.038  104.298        1.0  178.526  145.217        1.0
# 298             168.685  104.298        1.0  177.868  149.197        1.0
# 299             152.588  109.944        1.0  169.805  157.076        1.0
#
# individuals                                            ... individual2  \
# bodyparts   Right_ear                     Center_head  ...      Tail_3
# coords              x        y likelihood           x  ...  likelihood
# 0             257.463  173.267        1.0     238.724  ...         1.0
# 1             257.463  174.738        1.0     238.724  ...         1.0
# 2             257.463  174.765        1.0     238.724  ...         1.0
# 3             246.330  174.738        1.0     233.004  ...         1.0
# 4             227.374  174.738        1.0     217.341  ...         1.0
# ..                ...      ...        ...         ...  ...         ...
# 295           237.545  144.821        1.0     220.940  ...         1.0
# 296           222.024  137.630        1.0     199.529  ...         1.0
# 297           212.400  137.436        1.0     188.571  ...         1.0
# 298           207.272  137.055        1.0     183.990  ...         1.0
# 299           198.744  136.961        1.0     170.624  ...         1.0
#
# individuals                                                            \
# bodyparts     Tail_4                     Tail_tip
# coords             x        y likelihood        x        y likelihood
# 0            423.921  351.102        1.0    0.000    0.000        0.0
# 1            438.924  351.480        1.0  407.720  345.220        1.0
# 2            463.872  351.480        1.0  462.463  355.197        1.0
# 3            477.159  351.102        1.0  449.550  352.407        1.0
# 4            481.186  350.615        1.0  454.283  352.869        1.0
# ..               ...      ...        ...      ...      ...        ...
# 295          370.474  232.376        1.0  375.052  201.370        1.0
# 296          362.226  248.608        1.0  373.461  215.181        1.0
# 297          349.446  248.608        1.0  358.917  221.207        1.0
# 298          336.153  249.488        1.0  345.293  221.278        1.0
# 299          336.089  254.281        1.0  345.293  221.401        1.0
#
# individuals
# bodyparts   Center of mass
# coords                   x           y likelihood
# 0               503.961647  196.481118        1.0
# 1               509.082235  196.485765        1.0
# 2               510.545706  196.535294        1.0
# 3               512.343647  194.466647        1.0
# 4               515.643059  193.884647        1.0
# ..                     ...         ...        ...
# 295             223.706941  352.824235        1.0
# 296             205.261118  354.913176        1.0
# 297             190.871000  356.037353        1.0
# 298             185.001000  355.721412        1.0
# 299             174.851235  355.103294        1.0
#
# [300 rows x 138 columns]

# %% [markdown]
# ### Pre-process all the files

# %%
importlib.reload(dataloader)
# Out:
# <module 'dataloader' from 'c:\\Users\\Usuario\\Documents\\Documents\\MVA\\Stage\\DLCProject\\Code\\ENC-DEC\\src\\dataloader.py'>

# %%
data_dlc = dataloader.DataDLC(r'c:\Users\Usuario\Documents\Documents\MVA\Stage\DLCProject\Data\DataLoaderTestFormatMDX5CV_pre_processed\MDXCV_mal_Test 10DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered_filtered_filtered.h5')

# %%
video_path = r'c:\Users\Usuario\Documents\Documents\MVA\Stage\DLCProject\Data\AnalyzedVideos\MDX5CV male videos\MDXCV_mal_Test_10.mp4'
output_path = r'C:\Users\Usuario\Documents\Documents\MVA\Stage\DLCProject\Data\DataLoaderTestFormatMDX5CV_pre_processed\MDXCV_mal_Test_10_created.mp4'
data_dlc.create_video(video_path, output_path)
# Out:
# 100%|██████████| 2633/2633 [02:22<00:00, 18.48it/s]

# %%
x = data_dlc.coords['individual1'].loc[:, ('Tail_4', 'x')]
y = data_dlc.coords['individual1'].loc[:, ('Tail_4', 'y')]
# Detect tracklets 

tracklets = data_dlc.detect_tracklets(x, y, threshold=40)

# %%
folder_path = r'C:\Users\Usuario\Documents\Documents\MVA\Stage\DLCProject\Data\DataLoaderTestFormatMDX5CV_pre_processed'

for file in os.listdir(folder_path):
    if file.endswith('.h5'):
        print(file)
        data_path = os.path.join(folder_path, file)
        data_dlc = dataloader.DataDLC(data_path)
        data_dlc.preprocess()
        data_dlc.iterative_jump_detection(threshold_hard=[300,200], threshold_soft_min=20, threshold_soft_max=8,  verbose=True, tol=1e-9)
        data_dlc.remove_outlier_bouts(threshold_split_tracklets=40, threshold_jump=150, percentage_gap_neigh=0.2, verbose=True)
        data_dlc.save(data_path.replace('.h5', '_filtered.h5'))
# Out:
# MDXCV_mal_Test 10DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 27
# Outlier bout detected between 1028 and 1028  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 247.94318392123628
# Outlier bout detected between 990 and 990  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 170.4980227099423
# Outlier bout detected between 990 and 990  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 207.94379498797264
# Outlier bout detected between 1035 and 1037  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 327.64164670719134
# Outlier bout detected between 1193 and 1194  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 181.00462070621293
# Outlier bout detected between 1286 and 1288  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 290.8831862328932
# MDXCV_mal_Test 10DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 3
# MDXCV_mal_Test 11DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 57
# Outlier bout detected between 548 and 550  of individual individual1 and body part Nose
# 	 Jump between tracklet is 161.07138624224976
# Outlier bout detected between 1744 and 1744  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 184.96859904589212
# Outlier bout detected between 1744 and 1744  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 187.70150904294832
# Outlier bout detected between 2050 and 2055  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 159.46438330862475
# Outlier bout detected between 2193 and 2196  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 171.26823114927066
# Outlier bout detected between 359 and 359  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 184.78149733401335
# Outlier bout detected between 360 and 362  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 184.78149733401335
# Outlier bout detected between 2195 and 2197  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 206.37833770529312
# Outlier bout detected between 548 and 550  of individual individual2 and body part Nose
# 	 Jump between tracklet is 173.77555350508882
# Outlier bout detected between 1148 and 1148  of individual individual2 and body part Tail_1
# 	 Jump between tracklet is 160.68565304033837
# Outlier bout detected between 2050 and 2055  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 167.20672531031755
# Outlier bout detected between 2056 and 2059  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 155.4672991275014
# Outlier bout detected between 363 and 363  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 192.1315186246129
# Outlier bout detected between 1092 and 1092  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 171.13300000000004
# MDXCV_mal_Test 12DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 18
# Outlier bout detected between 1849 and 1849  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 168.22271232208803
# Outlier bout detected between 1850 and 1850  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 167.05399999999997
# Outlier bout detected between 396 and 396  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 171.28277198247346
# Outlier bout detected between 952 and 953  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 158.08989427537736
# Outlier bout detected between 1840 and 1843  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 177.58628259243451
# Outlier bout detected between 1844 and 1857  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 194.76158042591462
# Outlier bout detected between 1858 and 1858  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 189.07140988526004
# Outlier bout detected between 1680 and 1685  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 219.1465429067956
# Outlier bout detected between 1840 and 1840  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 179.61673045125838
# Outlier bout detected between 819 and 878  of individual individual2 and body part Nose
# 	 Jump between tracklet is 157.3551895553496
# Outlier bout detected between 820 and 1032  of individual individual2 and body part Tail_1
# 	 Jump between tracklet is 154.5792326025718
# Outlier bout detected between 952 and 953  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 156.63823810615338
# Outlier bout detected between 1394 and 1396  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 163.73382492631143
# Outlier bout detected between 1861 and 1869  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 204.19932232992352
# Outlier bout detected between 2134 and 2154  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 160.70257671860767
# Outlier bout detected between 880 and 880  of individual individual2 and body part Tail_base
# 	 Jump between tracklet is 168.10264126419904
# Outlier bout detected between 882 and 1035  of individual individual2 and body part Tail_base
# 	 Jump between tracklet is 164.1162220927596
# Outlier bout detected between 269 and 271  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 207.79199999999997
# Outlier bout detected between 1833 and 1833  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 166.61552936326194
# Outlier bout detected between 2134 and 2155  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 162.78680047227417
# Outlier bout detected between 2219 and 2230  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 254.35802108052343
# MDXCV_mal_Test 13DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 18
# Outlier bout detected between 253 and 321  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 185.73600000000005
# Outlier bout detected between 671 and 674  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 153.62655922072847
# Outlier bout detected between 669 and 670  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 190.05644801742454
# Outlier bout detected between 671 and 672  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 189.99252061331256
# Outlier bout detected between 673 and 673  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 180.075906050754
# Outlier bout detected between 674 and 683  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 181.79358829177664
# Outlier bout detected between 684 and 686  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 178.71947654634624
# Outlier bout detected between 2252 and 2255  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 165.0443284848044
# Outlier bout detected between 2256 and 2257  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 187.04643725289188
# Outlier bout detected between 2258 and 2262  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 185.75515093261885
# Outlier bout detected between 243 and 245  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 269.3484934448307
# Outlier bout detected between 634 and 657  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 213.35643349334467
# Outlier bout detected between 658 and 659  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 229.08941999577368
# Outlier bout detected between 669 and 670  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 221.7893274122991
# Outlier bout detected between 671 and 672  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 221.53074704203024
# Outlier bout detected between 673 and 673  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 212.90804925366257
# Outlier bout detected between 674 and 683  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 215.572214633519
# Outlier bout detected between 684 and 686  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 211.99673473192925
# Outlier bout detected between 990 and 993  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 186.05937310439373
# Outlier bout detected between 994 and 1000  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 184.1640893035339
# Outlier bout detected between 1049 and 1050  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 204.881
# Outlier bout detected between 1052 and 1061  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 206.41484406408372
# Outlier bout detected between 1062 and 1069  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 227.67784930686605
# Outlier bout detected between 2252 and 2255  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 153.90097037056006
# Outlier bout detected between 2256 and 2257  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 169.09971086019038
# Outlier bout detected between 2258 and 2262  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 171.52069066150588
# Outlier bout detected between 2263 and 2265  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 167.92621237317297
# Outlier bout detected between 245 and 252  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 290.80416517305935
# Outlier bout detected between 671 and 675  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 240.1508983722526
# Outlier bout detected between 676 and 680  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 235.3802964098737
# Outlier bout detected between 681 and 686  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 233.96845944913173
# Outlier bout detected between 995 and 996  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 180.471
# Outlier bout detected between 1050 and 1050  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 190.42146400550544
# Outlier bout detected between 1052 and 1059  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 205.6732214800945
# Outlier bout detected between 2223 and 2224  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 183.51272437899232
# Outlier bout detected between 2463 and 2464  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 167.1492676173007
# Outlier bout detected between 245 and 251  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 291.5843588843544
# Outlier bout detected between 252 and 270  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 271.66079884480945
# Outlier bout detected between 275 and 275  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 217.51201074883198
# Outlier bout detected between 543 and 547  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 162.70623064283677
# Outlier bout detected between 630 and 632  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 221.61936003878358
# Outlier bout detected between 633 and 659  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 226.93793200124125
# Outlier bout detected between 660 and 666  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 265.1976855423139
# Outlier bout detected between 667 and 670  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 252.5666152206186
# Outlier bout detected between 671 and 675  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 252.27271370483174
# Outlier bout detected between 676 and 680  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 251.81363251817803
# Outlier bout detected between 681 and 688  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 253.0249712933488
# Outlier bout detected between 1089 and 1093  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 180.0851315489427
# Outlier bout detected between 1094 and 1096  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 180.56975840378144
# Outlier bout detected between 1107 and 1113  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 218.83576536069236
# Outlier bout detected between 1402 and 1404  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 150.38296398528658
# Outlier bout detected between 2236 and 2238  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 215.02580370969437
# Outlier bout detected between 2464 and 2464  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 198.54949654934913
# Outlier bout detected between 2570 and 2570  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 182.5835717089574
# Outlier bout detected between 249 and 252  of individual individual2 and body part Tail_1
# 	 Jump between tracklet is 208.637
# Outlier bout detected between 671 and 674  of individual individual2 and body part Tail_1
# 	 Jump between tracklet is 156.9446614574704
# Outlier bout detected between 1031 and 1039  of individual individual2 and body part Tail_1
# 	 Jump between tracklet is 163.78550076548288
# Outlier bout detected between 1040 and 1043  of individual individual2 and body part Tail_1
# 	 Jump between tracklet is 178.3331393908603
# Outlier bout detected between 631 and 633  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 198.69982494707946
# Outlier bout detected between 669 and 670  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 191.66448742790092
# Outlier bout detected between 671 and 672  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 189.1247510454409
# Outlier bout detected between 673 and 673  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 184.50358689196264
# Outlier bout detected between 704 and 707  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 176.15946299021238
# Outlier bout detected between 708 and 716  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 168.45390379566751
# Outlier bout detected between 717 and 726  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 191.54787861263307
# Outlier bout detected between 1009 and 1044  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 169.89548283871468
# Outlier bout detected between 2201 and 2201  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 153.7710699253926
# Outlier bout detected between 631 and 633  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 227.84733181891775
# Outlier bout detected between 659 and 660  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 236.2308430751582
# Outlier bout detected between 669 and 670  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 223.21692194141556
# Outlier bout detected between 671 and 672  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 220.73645150948678
# Outlier bout detected between 673 and 673  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 216.46617869080612
# Outlier bout detected between 674 and 683  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 210.77724220607877
# Outlier bout detected between 704 and 707  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 206.49598734115878
# Outlier bout detected between 708 and 716  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 205.7012950202308
# Outlier bout detected between 717 and 726  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 225.0750909718799
# Outlier bout detected between 745 and 745  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 159.5774655081349
# Outlier bout detected between 993 and 993  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 182.97999999999996
# Outlier bout detected between 1014 and 1031  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 186.10994477727405
# Outlier bout detected between 1053 and 1061  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 219.91342627952483
# Outlier bout detected between 1062 and 1068  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 226.64217792149813
# Outlier bout detected between 1069 and 1071  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 208.07399999999998
# Outlier bout detected between 664 and 664  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 261.7444808396158
# Outlier bout detected between 671 and 675  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 242.70353716623086
# Outlier bout detected between 676 and 680  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 237.40215477749987
# Outlier bout detected between 681 and 686  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 236.97995995020338
# Outlier bout detected between 704 and 707  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 240.56632453442026
# Outlier bout detected between 2463 and 2464  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 161.56727666826595
# Outlier bout detected between 150 and 154  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 263.10956749232815
# Outlier bout detected between 262 and 262  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 262.9737211585979
# Outlier bout detected between 272 and 273  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 214.52633209235643
# Outlier bout detected between 630 and 632  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 228.15041898274046
# Outlier bout detected between 666 and 666  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 254.58777130883564
# Outlier bout detected between 667 and 670  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 252.30578711753722
# Outlier bout detected between 671 and 675  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 255.05978974742376
# Outlier bout detected between 676 and 682  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 252.23379247436296
# Outlier bout detected between 683 and 687  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 253.58304209272353
# Outlier bout detected between 704 and 707  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 247.49908152152807
# Outlier bout detected between 1094 and 1094  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 183.082
# Outlier bout detected between 1121 and 1122  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 162.20965835609175
# Outlier bout detected between 2461 and 2464  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 218.9623007026552
# Outlier bout detected between 2561 and 2561  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 150.83360454901953
# MDXCV_mal_Test 14DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 32
# Outlier bout detected between 1671 and 1671  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 159.1906050148689
# Outlier bout detected between 125 and 125  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 183.88440439852423
# Outlier bout detected between 131 and 131  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 235.22142475548435
# Outlier bout detected between 311 and 312  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 246.8142701587572
# Outlier bout detected between 1447 and 1458  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 220.15327433631325
# Outlier bout detected between 1463 and 1464  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 156.88
# Outlier bout detected between 1799 and 1799  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 231.68817250994925
# Outlier bout detected between 232 and 232  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 188.3941012346193
# Outlier bout detected between 1449 and 1458  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 235.27813715898043
# Outlier bout detected between 1678 and 1678  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 217.05129897791443
# Outlier bout detected between 1198 and 1199  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 159.56600781181433
# Outlier bout detected between 1086 and 1118  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 255.46158310986797
# Outlier bout detected between 1431 and 1431  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 182.42499999999998
# Outlier bout detected between 2253 and 2253  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 214.36567428578672
# Outlier bout detected between 2254 and 2258  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 227.27400000000006
# Outlier bout detected between 967 and 967  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 202.95259951525625
# Outlier bout detected between 1467 and 1470  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 160.0502822646683
# Outlier bout detected between 2076 and 2076  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 175.56215566003968
# MDXCV_mal_Test 15DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 34
# Outlier bout detected between 1504 and 1510  of individual individual1 and body part Right_ear
# 	 Jump between tracklet is 211.96264256231566
# Outlier bout detected between 1206 and 1209  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 159.50900707483572
# Outlier bout detected between 1210 and 1212  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 170.7985964140221
# Outlier bout detected between 288 and 289  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 154.21232055189364
# Outlier bout detected between 1190 and 1190  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 170.10199999999998
# Outlier bout detected between 1205 and 1207  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 158.88799999999998
# Outlier bout detected between 357 and 357  of individual individual2 and body part Left_ear
# 	 Jump between tracklet is 167.56884916057635
# Outlier bout detected between 728 and 728  of individual individual2 and body part Left_ear
# 	 Jump between tracklet is 197.26399999999998
# Outlier bout detected between 1264 and 1276  of individual individual2 and body part Left_ear
# 	 Jump between tracklet is 169.39072025645322
# Outlier bout detected between 1277 and 1314  of individual individual2 and body part Left_ear
# 	 Jump between tracklet is 187.82298942621478
# Outlier bout detected between 2095 and 2099  of individual individual2 and body part Left_ear
# 	 Jump between tracklet is 199.16804808000708
# Outlier bout detected between 2100 and 2104  of individual individual2 and body part Left_ear
# 	 Jump between tracklet is 210.76610847572246
# Outlier bout detected between 2105 and 2109  of individual individual2 and body part Left_ear
# 	 Jump between tracklet is 214.66728373927873
# Outlier bout detected between 2173 and 2177  of individual individual2 and body part Left_ear
# 	 Jump between tracklet is 245.6828976750315
# Outlier bout detected between 2178 and 2182  of individual individual2 and body part Left_ear
# 	 Jump between tracklet is 208.97250286102235
# Outlier bout detected between 2183 and 2185  of individual individual2 and body part Left_ear
# 	 Jump between tracklet is 218.52218880928316
# Outlier bout detected between 96 and 96  of individual individual2 and body part Right_ear
# 	 Jump between tracklet is 187.14169545293748
# Outlier bout detected between 1374 and 1376  of individual individual2 and body part Right_ear
# 	 Jump between tracklet is 152.40008737530303
# Outlier bout detected between 2043 and 2043  of individual individual2 and body part Right_ear
# 	 Jump between tracklet is 209.46586609755775
# Outlier bout detected between 2045 and 2047  of individual individual2 and body part Right_ear
# 	 Jump between tracklet is 208.24344599530616
# Outlier bout detected between 2048 and 2048  of individual individual2 and body part Right_ear
# 	 Jump between tracklet is 190.60455249547425
# Outlier bout detected between 2049 and 2049  of individual individual2 and body part Right_ear
# 	 Jump between tracklet is 191.97142127410527
# Outlier bout detected between 2092 and 2094  of individual individual2 and body part Right_ear
# 	 Jump between tracklet is 266.5651502072242
# Outlier bout detected between 2388 and 2392  of individual individual2 and body part Right_ear
# 	 Jump between tracklet is 248.839038265703
# Outlier bout detected between 1214 and 1219  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 174.89932878659081
# Outlier bout detected between 223 and 223  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 181.25539772652286
# Outlier bout detected between 1226 and 1229  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 157.59306713812003
# Outlier bout detected between 1230 and 1244  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 157.57111589374495
# Outlier bout detected between 288 and 288  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 228.91370617330892
# Outlier bout detected between 289 and 291  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 233.1316418185228
# Outlier bout detected between 292 and 292  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 231.88509431397273
# Outlier bout detected between 1209 and 1212  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 171.13655698593445
# MDXCV_mal_Test 16DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 38
# Outlier bout detected between 714 and 717  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 183.7342026651543
# Outlier bout detected between 1553 and 1553  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 157.05244531684312
# Outlier bout detected between 1285 and 1287  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 158.744679545489
# Outlier bout detected between 1557 and 1557  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 201.411
# Outlier bout detected between 1558 and 1559  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 196.40112954868667
# Outlier bout detected between 728 and 729  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 191.95237380141984
# Outlier bout detected between 730 and 730  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 194.35796188476561
# Outlier bout detected between 796 and 796  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 163.1103815120301
# Outlier bout detected between 1003 and 1005  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 214.56595476682685
# Outlier bout detected between 2205 and 2205  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 160.2485996849894
# Outlier bout detected between 2207 and 2208  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 183.16754371066943
# Outlier bout detected between 63 and 73  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 217.34978331022097
# Outlier bout detected between 395 and 395  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 330.19319697716367
# Outlier bout detected between 739 and 740  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 153.4269427088997
# Outlier bout detected between 741 and 746  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 153.4269427088997
# Outlier bout detected between 994 and 995  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 232.39327028121963
# Outlier bout detected between 997 and 999  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 228.36861803014878
# Outlier bout detected between 1000 and 1000  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 214.69621416550407
# Outlier bout detected between 1001 and 1002  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 210.38714497801428
# Outlier bout detected between 2205 and 2205  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 184.54081068695896
# Outlier bout detected between 2207 and 2210  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 219.96513853335946
# Outlier bout detected between 2412 and 2420  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 157.76795170439402
# Outlier bout detected between 505 and 508  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 267.9097399666537
# Outlier bout detected between 1581 and 1581  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 162.885
# Outlier bout detected between 505 and 508  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 289.60586603520306
# Outlier bout detected between 536 and 541  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 159.51105086482252
# Outlier bout detected between 714 and 728  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 370.8651185606433
# Outlier bout detected between 1611 and 1613  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 164.87959692151117
# MDXCV_mal_Test 17DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 29
# Outlier bout detected between 1141 and 1147  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 161.5390463169818
# Outlier bout detected between 1148 and 1179  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 156.42062589377397
# Outlier bout detected between 1141 and 1147  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 187.09386331197504
# Outlier bout detected between 1148 and 1169  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 181.73486837698482
# Outlier bout detected between 1174 and 1183  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 155.34810423690405
# Outlier bout detected between 1198 and 1198  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 194.2031324670125
# Outlier bout detected between 1148 and 1163  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 183.9673452028919
# Outlier bout detected between 1164 and 1164  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 211.15789726410898
# Outlier bout detected between 1165 and 1167  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 211.15789726410898
# Outlier bout detected between 1173 and 1174  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 182.6248644462194
# Outlier bout detected between 1175 and 1175  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 180.87592033490805
# Outlier bout detected between 1176 and 1176  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 161.20473148453178
# Outlier bout detected between 746 and 746  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 211.56279688073704
# Outlier bout detected between 1174 and 1175  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 178.69848530415695
# Outlier bout detected between 1176 and 1177  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 197.43459520813468
# Outlier bout detected between 1817 and 1817  of individual individual2 and body part Tail_1
# 	 Jump between tracklet is 193.4411452225198
# Outlier bout detected between 88 and 90  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 195.30167993645114
# Outlier bout detected between 1170 and 1173  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 183.81117274257298
# Outlier bout detected between 1209 and 1209  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 160.44338485895892
# Outlier bout detected between 2588 and 2591  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 174.09592731020447
# Outlier bout detected between 84 and 84  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 220.2052032128215
# Outlier bout detected between 173 and 173  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 198.252785092669
# Outlier bout detected between 1165 and 1166  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 209.99056428563642
# Outlier bout detected between 1168 and 1175  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 207.70538215944237
# Outlier bout detected between 1176 and 1177  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 163.80783641816404
# Outlier bout detected between 1178 and 1181  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 164.3720412631053
# Outlier bout detected between 1212 and 1215  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 164.38446643463607
# Outlier bout detected between 745 and 746  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 199.25741330249173
# Outlier bout detected between 1554 and 1583  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 151.73362218374675
# MDXCV_mal_Test 18DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 23
# Outlier bout detected between 446 and 447  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 180.0094381636696
# Outlier bout detected between 448 and 455  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 179.02867424242407
# Outlier bout detected between 446 and 446  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 206.99765002047727
# Outlier bout detected between 139 and 141  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 206.03000000000003
# Outlier bout detected between 2081 and 2081  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 274.0679208243825
# Outlier bout detected between 2082 and 2121  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 273.2674540738432
# Outlier bout detected between 139 and 141  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 194.81600000000003
# Outlier bout detected between 142 and 145  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 213.69004621179715
# Outlier bout detected between 2081 and 2082  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 287.16954814185993
# Outlier bout detected between 2083 and 2083  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 286.48075218284737
# Outlier bout detected between 2084 and 2086  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 286.7822565580025
# Outlier bout detected between 2087 and 2094  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 286.9007837005678
# Outlier bout detected between 2095 and 2097  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 289.86433103954
# Outlier bout detected between 2098 and 2098  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 288.55903796796935
# Outlier bout detected between 2099 and 2105  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 284.8311830839453
# Outlier bout detected between 2106 and 2108  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 282.7772971385786
# Outlier bout detected between 2109 and 2119  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 283.1658224097676
# Outlier bout detected between 3 and 3  of individual individual2 and body part Nose
# 	 Jump between tracklet is 151.85110145468158
# Outlier bout detected between 80 and 88  of individual individual2 and body part Nose
# 	 Jump between tracklet is 166.84559689125754
# Outlier bout detected between 146 and 146  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 212.7463835932353
# Outlier bout detected between 714 and 714  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 151.8223127639676
# Outlier bout detected between 715 and 719  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 150.54575605443017
# Outlier bout detected between 777 and 779  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 214.76928928503722
# Outlier bout detected between 780 and 783  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 214.84097048049284
# Outlier bout detected between 784 and 787  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 215.04994099045925
# Outlier bout detected between 788 and 797  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 217.69312498560902
# Outlier bout detected between 798 and 800  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 219.81368150549682
# Outlier bout detected between 1680 and 1686  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 199.36930020692753
# Outlier bout detected between 2083 and 2086  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 287.27582449799013
# Outlier bout detected between 2087 and 2094  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 287.73223559587484
# Outlier bout detected between 2095 and 2097  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 289.2592202938395
# Outlier bout detected between 2098 and 2098  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 288.3581527545216
# Outlier bout detected between 2099 and 2105  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 287.44185495157103
# Outlier bout detected between 2106 and 2108  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 282.5653704543428
# Outlier bout detected between 2109 and 2119  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 282.74181265069376
# MDXCV_mal_Test 19DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 6
# Outlier bout detected between 1809 and 1810  of individual individual1 and body part Spine_center-2
# 	 Jump between tracklet is 150.77466884394076
# Outlier bout detected between 377 and 380  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 189.65451754440232
# Outlier bout detected between 376 and 381  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 197.61052025638716
# Outlier bout detected between 1528 and 1528  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 202.3283478161179
# Outlier bout detected between 374 and 381  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 217.20733579923126
# Outlier bout detected between 375 and 381  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 223.34563988804433
# Outlier bout detected between 521 and 521  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 238.055
# Outlier bout detected between 802 and 802  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 221.349
# Outlier bout detected between 803 and 813  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 232.04899999999998
# Outlier bout detected between 814 and 818  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 236.40749240453442
# Outlier bout detected between 1500 and 1500  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 261.927
# Outlier bout detected between 1529 and 1530  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 232.77806729372077
# Outlier bout detected between 1537 and 1537  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 234.82079700912354
# Outlier bout detected between 1809 and 1810  of individual individual1 and body part Tail_base
# 	 Jump between tracklet is 193.5402440966736
# Outlier bout detected between 376 and 380  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 240.89156124904005
# Outlier bout detected between 392 and 395  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 240.89967814009213
# Outlier bout detected between 815 and 818  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 236.51162701228876
# Outlier bout detected between 819 and 1022  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 240.00617182480954
# Outlier bout detected between 1338 and 1340  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 245.45299999999997
# Outlier bout detected between 2035 and 2035  of individual individual2 and body part Nose
# 	 Jump between tracklet is 161.2743973481222
# Outlier bout detected between 2036 and 2040  of individual individual2 and body part Nose
# 	 Jump between tracklet is 161.2743973481222
# Outlier bout detected between 377 and 380  of individual individual2 and body part Tail_1
# 	 Jump between tracklet is 181.31514636400348
# Outlier bout detected between 381 and 452  of individual individual2 and body part Tail_1
# 	 Jump between tracklet is 181.282926829859
# Outlier bout detected between 378 and 381  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 202.93081737626744
# Outlier bout detected between 382 and 451  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 199.06416244517746
# Outlier bout detected between 375 and 381  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 238.30391343198713
# Outlier bout detected between 376 and 380  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 242.15775254986158
# Outlier bout detected between 393 and 395  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 241.38053641915698
# Outlier bout detected between 744 and 746  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 333.76065429136486
# MDXCV_mal_Test 1DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 11
# Outlier bout detected between 2528 and 2537  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 159.74469532663676
# Outlier bout detected between 2538 and 2543  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 154.63047407610182
# Outlier bout detected between 318 and 326  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 170.81293974989134
# Outlier bout detected between 2053 and 2057  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 242.16096888020576
# Outlier bout detected between 321 and 326  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 161.6948097188033
# Outlier bout detected between 2516 and 2516  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 161.05367997347966
# Outlier bout detected between 2529 and 2537  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 159.86699999999996
# Outlier bout detected between 130 and 131  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 157.94631776967768
# Outlier bout detected between 320 and 326  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 171.2105970698076
# Outlier bout detected between 767 and 767  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 171.01805997028504
# Outlier bout detected between 2058 and 2152  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 257.12162119316224
# Outlier bout detected between 130 and 130  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 172.2668862114829
# Outlier bout detected between 321 and 326  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 179.76325504674196
# Outlier bout detected between 767 and 767  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 208.09765081326603
# Outlier bout detected between 1351 and 1359  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 162.45289970019002
# MDXCV_mal_Test 20DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 72
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 21
# Outlier bout detected between 1172 and 1173  of individual individual1 and body part Nose
# 	 Jump between tracklet is 169.24588307252853
# Outlier bout detected between 2018 and 2019  of individual individual1 and body part Right_ear
# 	 Jump between tracklet is 186.97099999999998
# Outlier bout detected between 753 and 755  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 245.46670992417685
# Outlier bout detected between 1328 and 1337  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 174.6440372443331
# Outlier bout detected between 1184 and 1185  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 172.11700000000002
# Outlier bout detected between 1428 and 1430  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 186.79935911292625
# Outlier bout detected between 1175 and 1325  of individual individual2 and body part Left_ear
# 	 Jump between tracklet is 153.58115324804666
# Outlier bout detected between 1336 and 1451  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 150.80948814978456
# Outlier bout detected between 1184 and 1185  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 187.03700000000003
# MDXCV_mal_Test 4DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 51
# Outlier bout detected between 2167 and 2169  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 158.28600731902995
# Outlier bout detected between 1236 and 1245  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 197.61133528722485
# Outlier bout detected between 1246 and 1250  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 201.45364063476237
# Outlier bout detected between 1355 and 1355  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 155.497
# Outlier bout detected between 2438 and 2445  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 156.9285368726797
# Outlier bout detected between 1432 and 1435  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 201.74055204891258
# Outlier bout detected between 2441 and 2441  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 202.8524754717083
# Outlier bout detected between 1236 and 1244  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 258.89648863010865
# Outlier bout detected between 1256 and 1256  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 273.6687158518488
# Outlier bout detected between 1482 and 1483  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 249.0403608253088
# Outlier bout detected between 2438 and 2441  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 230.37829942943847
# Outlier bout detected between 2282 and 2284  of individual individual2 and body part Center_head
# 	 Jump between tracklet is 161.49740357045994
# Outlier bout detected between 2282 and 2326  of individual individual2 and body part Left_mid
# 	 Jump between tracklet is 155.79522284075338
# Outlier bout detected between 1139 and 1141  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 253.4757728403249
# Outlier bout detected between 1236 and 1245  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 193.44656292630273
# Outlier bout detected between 1258 and 1351  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 207.977437223368
# Outlier bout detected between 2348 and 2348  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 237.37830573158956
# Outlier bout detected between 1236 and 1245  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 228.73132011598238
# Outlier bout detected between 1724 and 1724  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 222.332
# Outlier bout detected between 2348 and 2348  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 254.22784949725707
# Outlier bout detected between 1165 and 1165  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 232.76000000000002
# Outlier bout detected between 1236 and 1247  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 250.13005653259665
# Outlier bout detected between 1482 and 1483  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 249.25614156726405
# MDXCV_mal_Test 5DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 37
# Outlier bout detected between 1280 and 1280  of individual individual1 and body part Nose
# 	 Jump between tracklet is 203.2982551671312
# Outlier bout detected between 1281 and 1281  of individual individual1 and body part Nose
# 	 Jump between tracklet is 210.48025980837255
# Outlier bout detected between 1608 and 1613  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 198.43742164470893
# Outlier bout detected between 1614 and 1632  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 193.7383324615963
# Outlier bout detected between 1648 and 1648  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 157.155
# Outlier bout detected between 1649 and 1676  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 157.1635778066916
# Outlier bout detected between 1605 and 1630  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 217.0648506092131
# Outlier bout detected between 2287 and 2359  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 222.24566843922963
# Outlier bout detected between 460 and 558  of individual individual2 and body part Tail_2
# 	 Jump between tracklet is 197.1042455808601
# Outlier bout detected between 807 and 811  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 151.62927693885507
# MDXCV_mal_Test 6DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 19
# Outlier bout detected between 1464 and 1465  of individual individual1 and body part Left_bhip
# 	 Jump between tracklet is 157.72121825867308
# Outlier bout detected between 1466 and 1470  of individual individual1 and body part Left_bhip
# 	 Jump between tracklet is 155.39890857403083
# Outlier bout detected between 1672 and 1673  of individual individual1 and body part Left_bhip
# 	 Jump between tracklet is 194.07741995399667
# Outlier bout detected between 880 and 885  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 159.33694559956893
# Outlier bout detected between 1424 and 1429  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 212.46592578575985
# Outlier bout detected between 1430 and 1430  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 215.3979929525807
# Outlier bout detected between 1673 and 1673  of individual individual1 and body part Tail_1
# 	 Jump between tracklet is 301.1289601101162
# Outlier bout detected between 175 and 177  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 165.26588851000076
# Outlier bout detected between 883 and 883  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 176.9574891803113
# Outlier bout detected between 1425 and 1428  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 230.25637291071877
# Outlier bout detected between 1429 and 1431  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 228.52901707441876
# Outlier bout detected between 1672 and 1675  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 307.04483572436135
# Outlier bout detected between 1712 and 1713  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 259.56466916743506
# Outlier bout detected between 1714 and 1743  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 274.99006246226423
# Outlier bout detected between 1744 and 1748  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 271.69938087894127
# Outlier bout detected between 1999 and 2002  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 199.321176647139
# Outlier bout detected between 175 and 179  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 214.98368976506097
# Outlier bout detected between 1425 and 1428  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 235.06451683739934
# Outlier bout detected between 1459 and 1463  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 277.34591496000075
# Outlier bout detected between 1464 and 1465  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 277.0063822513843
# Outlier bout detected between 1466 and 1470  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 276.79634788233744
# Outlier bout detected between 1503 and 1503  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 232.16392860218403
# Outlier bout detected between 1672 and 1675  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 286.7769072153475
# Outlier bout detected between 1712 and 1713  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 248.65676329631575
# Outlier bout detected between 1714 and 1743  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 273.78837973880485
# Outlier bout detected between 1744 and 1747  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 268.2326445196408
# Outlier bout detected between 177 and 178  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 177.0665307532736
# Outlier bout detected between 880 and 885  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 193.3580031185676
# Outlier bout detected between 1424 and 1429  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 233.34829329780837
# Outlier bout detected between 1459 and 1463  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 282.39065776508966
# Outlier bout detected between 1464 and 1465  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 285.0033914622772
# Outlier bout detected between 1466 and 1470  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 285.284248259521
# Outlier bout detected between 1673 and 1673  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 253.4766830499405
# Outlier bout detected between 1739 and 1748  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 258.08166081688177
# Outlier bout detected between 177 and 178  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 219.20631341729188
# Outlier bout detected between 324 and 326  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 156.398
# Outlier bout detected between 880 and 885  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 203.81409515536453
# Outlier bout detected between 1424 and 1429  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 211.0665465889846
# Outlier bout detected between 1459 and 1463  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 267.65094445751544
# Outlier bout detected between 1464 and 1465  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 269.5361833706191
# Outlier bout detected between 1466 and 1470  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 269.3733146434517
# Outlier bout detected between 1501 and 1501  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 250.3703258714978
# Outlier bout detected between 1502 and 1528  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 251.15118087717605
# Outlier bout detected between 1941 and 1941  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 157.01371497420212
# Outlier bout detected between 177 and 178  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 189.75778005130647
# Outlier bout detected between 185 and 195  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 154.32259500150974
# Outlier bout detected between 196 and 234  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 161.263624184129
# Outlier bout detected between 235 and 237  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 150.87474159049947
# MDXCV_mal_Test 7DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 12
# Outlier bout detected between 2084 and 2084  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 183.0652059485909
# Outlier bout detected between 2084 and 2084  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 201.30983430771582
# Outlier bout detected between 781 and 781  of individual individual2 and body part Tail_3
# 	 Jump between tracklet is 175.22938919313737
# Outlier bout detected between 781 and 782  of individual individual2 and body part Tail_4
# 	 Jump between tracklet is 209.25412007891265
# MDXCV_mal_Test 8DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 13
# Outlier bout detected between 263 and 265  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 151.0607098520327
# Outlier bout detected between 733 and 733  of individual individual1 and body part Tail_tip
# 	 Jump between tracklet is 161.1615155209208
# Outlier bout detected between 2608 and 2608  of individual individual2 and body part Center_head
# 	 Jump between tracklet is 278.46524632169087
# Outlier bout detected between 2629 and 2633  of individual individual2 and body part Right_fhip
# 	 Jump between tracklet is 225.8970356998958
# Outlier bout detected between 1081 and 1126  of individual individual2 and body part Tail_tip
# 	 Jump between tracklet is 157.82865345050627
# MDXCV_mal_Test 9DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 27
# Outlier bout detected between 764 and 785  of individual individual1 and body part Nose
# 	 Jump between tracklet is 157.571
# Outlier bout detected between 1606 and 1607  of individual individual1 and body part Tail_2
# 	 Jump between tracklet is 156.95600000000002
# Outlier bout detected between 1610 and 1614  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 174.59209100357324
# Outlier bout detected between 1615 and 1621  of individual individual1 and body part Tail_3
# 	 Jump between tracklet is 167.64349844237915
# Outlier bout detected between 1408 and 1411  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 157.33664839763176
# Outlier bout detected between 1617 and 1620  of individual individual1 and body part Tail_4
# 	 Jump between tracklet is 176.1132748943134
# Outlier bout detected between 682 and 686  of individual individual2 and body part Tail_1
# 	 Jump between tracklet is 154.24939871843907

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Check the tracklet splitting

# %%
importlib.reload(dataloader)


data_path = r'c:\Users\Usuario\Documents\Documents\MVA\Stage\DLCProject\Data\AnalyzedVideos\MDX5CV_DLC_analyzed\MDXCV_mal_Test 1DLC_dlcrnetms5_More_BodyPartsJul9shuffle1_740000_el_filtered.h5'

data_dlc = dataloader.DataDLC(data_path)

# %%
 # For each time-series
for ind in self.individuals:
    for body_part in self.body_parts:
        x = self.coords[ind].loc[:, (body_part, 'x')]
        y = self.coords[ind].loc[:, (body_part, 'y')]
        # Detect tracklets 
        tracklets = self.detect_tracklets(x, y, threshold=100)
        
        for t in range(1, len(tracklets)-1):
            # Check if tracklet is a jump
            jump_before_x = tracklets[t]['Coords_x'].iloc[0] - tracklets[t-1]['Coords_x'].iloc[-1]
            jump_before_y = tracklets[t]['Coords_y'].iloc[0] - tracklets[t-1]['Coords_y'].iloc[-1]
            nans_between_before = tracklets[t]['Frames'].iloc[0] - tracklets[t-1]['Frames'].iloc[-1] - 1
            jump_after_x = tracklets[t+1]['Coords_x'].iloc[0] - tracklets[t]['Coords_x'].iloc[-1]
            jump_after_y = tracklets[t+1]['Coords_y'].iloc[0] - tracklets[t]['Coords_y'].iloc[-1]
            nans_between_after = tracklets[t+1]['Frames'].iloc[0] - tracklets[t]['Frames'].iloc[-1] - 1
            if nans_between_before > 0:
                jump_before = np.sqrt(jump_before_x**2 + jump_before_y**2)/nans_between_before
            else:
                jump_before = np.sqrt(jump_before_x**2 + jump_before_y**2)
            if nans_between_after > 0:
                jump_after = np.sqrt(jump_after_x**2 + jump_after_y**2)/nans_between_after
            else:
                jump_after = np.sqrt(jump_after_x**2 + jump_after_y**2)
            jump = (jump_before + jump_after)/2
            if jump > 150:
                # Set to NaN the tracklet
                self.coords[ind].loc[tracklets[t]['Frames'], (body_part, 'x')] = np.nan
                self.coords[ind].loc[tracklets[t]['Frames'], (body_part, 'y')] = np.nan
                self.coords[ind].loc[tracklets[t]['Frames'], (body_part, 'likelihood')] = 0
                self.mask_jumps[ind].loc[tracklets[t]['Frames'], body_part] = True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # For each time-series
# ----> 2 for ind in self.individuals:
#       3    for body_part in self.body_parts:
#       4        x = self.coords[ind].loc[:, (body_part, 'x')]
#
# NameError: name 'self' is not defined

# %%
# Plot the

# %% [markdown]
# # Save video

# %%
# Video_path 
video_path = r'c:\Users\Usuario\Documents\Documents\MVA\Stage\DLCProject\Data\AnalyzedVideos\MDX5CV male videos\MDXCV_mal_Test_1.mp4'
video_output_path = r'C:\Users\Usuario\Documents\Documents\MVA\Stage\DLCProject\Data\Test\MDXCV_mal_Test_1.mp4'

# Create video
data_dlc.create_video(video_path, video_output_path, plot_prev_coords=True)
# Out:
# 100%|██████████| 2624/2624 [05:31<00:00,  7.91it/s]

# %% [markdown]
# # Preprocess the data

# %%
folder_path = r'C:\Users\Usuario\Documents\Documents\MVA\Stage\DLCProject\Data\DataLoaderTestFormatMDX5CV_pre_processed'

# %%
for file in os.listdir(folder_path):
    if file.endswith('.h5'):
        data_path = os.path.join(folder_path, file)
        data_dlc = dataloader.DataDLC(data_path)
        data_dlc.preprocess()
        data_dlc.iterative_jump_detection(threshold_hard=[10000,10000], threshold_soft_min=30, threshold_soft_max=8,  verbose=True, tol=1e-9)
        data_dlc.remove_outlier_bouts(threshold_split_tracklets=40, threshold_jump=150, percentage_gap_neigh=0.2, verbose=True)
        data_dlc.save(data_path.replace('.h5', '_filtered.h5'))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Entropy of the mask: 0.0,  Number of jumps detected: 0
#
# Total number of jumps detected: 13
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[138], line 7
#       5 data_dlc.preprocess()
#       6 data_dlc.iterative_jump_detection(threshold_hard=[10000,10000], threshold_soft_min=30, threshold_soft_max=8,  verbose=True, tol=1e-9)
# ----> 7 data_dlc.remove_outlier_bouts(threshold_split_tracklets=40, threshold_jump=150, percentage_gap_neigh=0.2, verbose=True)
#       8 data_dlc.save(data_path.replace('.h5', '_filtered.h5'))
#
# File c:\Users\Usuario\Documents\Documents\MVA\Stage\DLCProject\Code\ENC-DEC\src\dataloader.py:316, in DataDLC.remove_outlier_bouts(self, threshold_split_tracklets, threshold_jump, percentage_gap_neigh, verbose)
#     312 tracklets = self.detect_tracklets(x, y, threshold=threshold_split_tracklets)
#     314 for t in range(1, len(tracklets)-1):
#     315     # Check if tracklet is a jump
# --> 316     jump_before_x = tracklets[t]['Coords_x'].iloc[0] - tracklets[t-1]['Coords_x'].iloc[-1]
#     317     jump_before_y = tracklets[t]['Coords_y'].iloc[0] - tracklets[t-1]['Coords_y'].iloc[-1]
#     318     nans_between_before = tracklets[t]['Frames'].iloc[0] - tracklets[t-1]['Frames'].iloc[-1] - 1
#
# File c:\Users\Usuario\anaconda3\envs\deepof\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Usuario\anaconda3\envs\deepof\lib\site-packages\pandas\core\indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\Usuario\anaconda3\envs\deepof\lib\site-packages\pandas\core\indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
#    1556 if key >= len_axis or key < -len_axis:
# -> 1557     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
